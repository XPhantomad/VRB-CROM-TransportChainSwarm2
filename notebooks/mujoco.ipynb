# %% [markdown]
# ## Quick Start: V-Shape Flocking Swarm

# %% [markdown]
# ### 1. Open a Virtual Desktop from the launcher
# ### 2. Open a terminal and run:

# %%
chmod +x ./Context-Role-Oriented-Transport-Chain-Swarm/VRBrun.sh &&
./Context-Role-Oriented-Transport-Chain-Swarm/VRBrun.sh

# %% [markdown]
# ### 3. Start the simulation in the Virtual Desktop in ARGoS3

# %% [markdown]
# ### 4. Open another terminal to start the Web App in chrome by running:

# %%
google-chrome \
  --no-sandbox \
  --disable-dev-shm-usage \
  --disable-extensions \
  "http://localhost:5000"
