# %% [markdown]
# ## Quick Start: Transport Chain Swarm

# %% [markdown]
# ### 1. Disable Simple-GUI in the bottom left corner
# ![image.png](attachment:image.png)
# ### 2. Open a new Tab and start a Desktop
# ### 3. Open a new Tab, start a Terminal and run:

# %%
cd .. &&
chmod +x ./Context-Role-Oriented-Transport-Chain-Swarm/VRBrun.sh &&
./Context-Role-Oriented-Transport-Chain-Swarm/VRBrun.sh

# %% [markdown]
# ### 3. Switch to the virutal Desktop and start the simulation in ARGoS3

# %% [markdown]
# ### 4. Open another terminal to start the Web App in chrome by running:

# %%
google-chrome \
  --no-sandbox \
  --disable-dev-shm-usage \
  --disable-extensions \
  "http://localhost:5000"
