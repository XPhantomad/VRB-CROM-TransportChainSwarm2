# %% [markdown]
# ## Quick Start: Transport Chain Swarm
#
# <button data-commandlinker-command="notebook:run-all-cells" class="jupyter-button" style="color: #fff;background-color: #1976d2;">Run All</button>

# %% [markdown]
# ### 1. Open a Virtual Desktop

# %%
import utils
utils.display_desktop()

# %% [markdown]
# ### 2. Execute the Simulation, Control Application and Dashboard with the following cell:

# %%
import subprocess
import utils
from IPython.display import display, IFrame
from time import sleep

# Shell script to start the simulation, control app, and dashboard
script = """
cd ..
chmod +x ./Context-Role-Oriented-Transport-Chain-Swarm/VRBrun.sh
./Context-Role-Oriented-Transport-Chain-Swarm/VRBrun.sh
"""

# Launch the script in a new terminal (background process)
subprocess.Popen(["gnome-terminal", "--", "bash", "-c", script])

# Wait for the dashboard to start
sleep(5)

# Get the proxy URL for the dashboard
url_prefix = utils.get_url_prefix()
dashboard_url = f"{url_prefix}/proxy/5000" if url_prefix else "http://localhost:5000"

# Display the dashboard in an iframe
print("Dashboard")
display(IFrame(src=dashboard_url, width="100%", height=600))

# %% [markdown]
# ### 3. Start the simulation in ARGoS3
# ![VNC-Desktop view.png](./VNC-Desktop%20view.png)

# %% [markdown]
# ### 4. Enjoy the Simulation:
# 4 Robots deliver load objects (black cylinders) from the prey to the nest collaboratively. They handover their load to form a chain with one head, one tail and two intermediates. The approach is completely decentralized and uses neither global communication nor centralized control. Communication is established via colored LEDs on each robot. The chain is daynamic thus if one robot fails the other robots overtake its role and form a wokring transport chain again. The Webapp visualized the currently exposed Message, Role, Team and some other useful parameters of each robot.
